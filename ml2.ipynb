# %% [markdown]
# <a href="https://colab.research.google.com/github/surekavin/ML/blob/main/ml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv("/content/petrol_consumption.csv")

# %%
dataset.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
dataset.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Petrol_tax                      float64
# Average_income                    int64
# Paved_Highways                    int64
# Population_Driver_licence(%)    float64
# Petrol_Consumption                int64
# dtype: object

# %%
dataset.drop_duplicates()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# 11        7.50            5126           14186                         0.525
# 12        7.00            4817            6930                         0.574
# 13        7.00            4207            6580                         0.545
# 14        7.00            4332            8159                         0.608
# 15        7.00            4318           10340                         0.586
# 16        7.00            4206            8508                         0.572
# 17        7.00            3718            4725                         0.540
# 18        7.00            4716            5915                         0.724
# 19        8.50            4341            6010                         0.677
# 20        7.00            4593            7834                         0.663
# 21        8.00            4983             602                         0.602
# 22        9.00            4897            2449                         0.511
# 23        9.00            4258            4686                         0.517
# 24        8.50            4574            2619                         0.551
# 25        9.00            3721            4746                         0.544
# 26        8.00            3448            5399                         0.548
# 27        7.50            3846            9061                         0.579
# 28        8.00            4188            5975                         0.563
# 29        9.00            3601            4650                         0.493
# 30        7.00            3640            6905                         0.518
# 31        7.00            3333            6594                         0.513
# 32        8.00            3063            6524                         0.578
# 33        7.50            3357            4121                         0.547
# 34        8.00            3528            3495                         0.487
# 35        6.58            3802            7834                         0.629
# 36        5.00            4045           17782                         0.566
# 37        7.00            3897            6385                         0.586
# 38        8.50            3635            3274                         0.663
# 39        7.00            4345            3905                         0.672
# 40        7.00            4449            4639                         0.626
# 41        7.00            3656            3985                         0.563
# 42        7.00            4300            3635                         0.603
# 43        7.00            3745            2611                         0.508
# 44        6.00            5215            2302                         0.672
# 45        9.00            4476            3942                         0.571
# 46        7.00            4296            4083                         0.623
# 47        7.00            5002            9794                         0.593
#
#     Petrol_Consumption
# 0                  541
# 1                  524
# 2                  561
# 3                  414
# 4                  410
# 5                  457
# 6                  344
# 7                  467
# 8                  464
# 9                  498
# 10                 580
# 11                 471
# 12                 525
# 13                 508
# 14                 566
# 15                 635
# 16                 603
# 17                 714
# 18                 865
# 19                 640
# 20                 649
# 21                 540
# 22                 464
# 23                 547
# 24                 460
# 25                 566
# 26                 577
# 27                 631
# 28                 574
# 29                 534
# 30                 571
# 31                 554
# 32                 577
# 33                 628
# 34                 487
# 35                 644
# 36                 640
# 37                 704
# 38                 648
# 39                 968
# 40                 587
# 41                 699
# 42                 632
# 43                 591
# 44                 782
# 45                 510
# 46                 610
# 47                 524

# %%
dataset.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
iqr=dataset.Paved_Highways.quantile(0.75)-dataset.Paved_Highways.quantile(0.25)
upper_threshold=dataset.Paved_Highways.quantile(0.75)+(1.5*iqr)
lower_threshold=dataset.Paved_Highways.quantile(0.25)-(1.5*iqr)
lower_threshold,upper_threshold
# Out:
# (-2958.375, 13224.625)

# %%
dataset.Paved_Highways=dataset.Paved_Highways.clip(-2958,13224)

# %%
dataset.shape
# Out:
# (48, 5)

# %%
iqr=dataset.Petrol_tax.quantile(0.75)-dataset.Petrol_tax.quantile(0.25)
upper_threshold=dataset.Petrol_tax.quantile(0.75)+(1.5*iqr)
lower_threshold=dataset.Petrol_tax.quantile(0.25)-(1.5*iqr)
lower_threshold,upper_threshold
# Out:
# (5.3125, 9.8125)

# %%
iqr=dataset.Average_income.quantile(0.75)-dataset.Average_income.quantile(0.25)
upper_threshold=dataset.Average_income.quantile(0.75)+(1.5*iqr)
lower_threshold=dataset.Average_income.quantile(0.25)-(1.5*iqr)
lower_threshold,upper_threshold
# Out:
# (2479.375, 5838.375)

# %%
iqr=dataset.Population_Driver_licence(%).quantile(0.75)-dataset.Population_Driver_licence(%).quantile(0.25)
upper_threshold=dataset.Population_Driver_licence(%).quantile(0.75)+(1.5*iqr)
lower_threshold=dataset.Population_Driver_licence(%).quantile(0.25)-(1.5*iqr)
lower_threshold,upper_threshold
# Out:
#   File "<ipython-input-32-30e244bd1c91>", line 1
#     iqr=dataset.Population_Driver_licence(%).quantile(0.75)-dataset.Population_Driver_licence(%).quantile(0.25)
#                                           ^
# SyntaxError: invalid syntax

# %%
dataset.groupby('Petrol_tax')['Petrol_Consumption'].mean()
# Out:
# Petrol_tax
# 5.00     640.000000
# 6.00     782.000000
# 6.58     644.000000
# 7.00     631.736842
# 7.50     536.000000
# 8.00     502.000000
# 8.50     582.666667
# 9.00     530.875000
# 10.00    457.000000
# Name: Petrol_Consumption, dtype: float64

# %%
dataset.groupby('Petrol_tax')['Petrol_Consumption'].mean().plot()
import matplotlib.pyplot as plt
plt.title("Tax vs Consumption")
plt.xlabel("Tax")
plt.ylabel("Consumption")
plt.show()

# %%
dataset[['Petrol_tax','Petrol_Consumption']].corr()
# Out:
#                     Petrol_tax  Petrol_Consumption
# Petrol_tax             1.00000            -0.45128
# Petrol_Consumption    -0.45128             1.00000

# %%
dataset.groupby('Average_income')['Petrol_Consumption'].mean().plot()
plt.title("Avg vs Consumption")
plt.xlabel("Avg")
plt.ylabel("Consumption")
plt.show()

# %%
dataset[['Average_income','Petrol_Consumption']].corr()
# Out:
#                     Average_income  Petrol_Consumption
# Average_income            1.000000           -0.244862
# Petrol_Consumption       -0.244862            1.000000

# %%
import numpy as np
dataset['transformed']=(dataset['Paved_Highways'])
dataset.plot(x='transformed',y='Petrol_Consumption',style='o')
plt.title('Paved Highway vs Consumption')
plt.xlabel('Transform Paved_Highways')
plt.ylabel('Consumption')
plt.show
dataset[['Paved_Highways','Petrol_Consumption']].corr()
# Out:
#                     Paved_Highways  Petrol_Consumption
# Paved_Highways            1.000000            0.009854
# Petrol_Consumption        0.009854            1.000000

# %%
dataset['logPaved_Highways']  = np.power(dataset['Paved_Highways'],2)

# %%
dataset.plot(x='Population_Driver_licence(%)',y='Petrol_Consumption',style='o')
plt.title('Driver License % vs consumption')
plt.xlabel('Driver License %')
plt.ylabel('Consumption')
plt.show()
dataset[['Population_Driver_licence(%)','Petrol_Consumption']].corr()
# Out:
#                               Population_Driver_licence(%)  Petrol_Consumption
# Population_Driver_licence(%)                      1.000000            0.698965
# Petrol_Consumption                                0.698965            1.000000

# %%
x=dataset[['Petrol_tax', 'Average_income', 'Population_Driver_licence(%)']].values
y=dataset['Petrol_Consumption']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(regressor.coef_,['Petrol_tax', 'Average_income',
       'Population_Driver_licence(%)'], columns=['Coefficient'])
y_pred = regressor.predict(x_test_scaled)
coeff_df
# Out:
#                               Coefficient
# Petrol_tax                     -31.607406
# Average_income                 -39.035549
# Population_Driver_licence(%)    70.845464

# %%
regressor.predict(scaler.transform(np.array([[11,5000,0.6]])))
# Out:
# array([442.89863494])

# %%
regressor.intercept_
# Out:
# 574.8421052631579

# %%
df=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df
# Out:
#     Actual   Predicted
# 2      561  561.771123
# 40     587  653.187110
# 35     644  714.419485
# 23     547  454.028755
# 11     471  459.837951
# 29     534  466.114479
# 0      541  509.669602
# 8      464  492.227469
# 39     968  719.806844
# 1      524  536.426009

# %%
from sklearn import metrics
print('R2-SCORE:',metrics.r2_score(y_test,y_pred))
# Out:
# R2-SCORE: 0.5414231214214926
